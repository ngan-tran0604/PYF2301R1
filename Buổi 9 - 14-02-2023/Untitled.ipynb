# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Nhập một số nguyên: "))
result = n * n
print(f"Bình phương của {n} là {result}")
# Out:
# Nhập một số nguyên: 2
# Bình phương của 2 là 4

# %%
title = "No.,Fullname,Math,Physics,Chemistry"
data = "1,Nguyen Van A,8.0,9.5,7.4"
#trích xuất ra các điểm và tính điểm trung bình

print(f"Math: {data[15:18]}")
print(f"Physics: {data[19:22]}")
print(f"Chemistry: {data[23:]}")

Math = float(data[15:18])
Physics = float(data[19:22])
Chemistry = float(data[23:])

dtb = round((Math + Physics + Chemistry)/3, 1)

print(f"Average_score: {dtb}")
# Out:
# Math: 8.0
# Physics: 9.5
# Chemistry: 7.4
# Average_score: 8.3
