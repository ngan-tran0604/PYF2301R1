# %%
class Patient:
    def __init__(self, name, age, height, weight):
        self.name = name
        self.age = age
        self.height = height
        self.weight = weight
        self.bmi = weight / height ** 2

# %%
# BMI Calculator

from tkinter import *
from tkinter.messagebox import showinfo

window = Tk()
window.title("Healthcare System")
window.geometry("500x300")

# Label
intro_lbl = Label(window, text="Healthcare System")
my_weight_lbl = Label(window, text="My weight(kg)")
my_height_lbl = Label(window, text="My heihgt(m)")
my_name_lbl = Label(window, text="My name")
my_age_lbl = Label(window, text="My age")
search_lbl = Label(window, text="Search:")

# Entry
weight = Entry(window)
height = Entry(window)
name = Entry(window)
age = Entry(window)
search_name = Entry(window)

# list_patient được sử dụng để lưu trữ thông tin các bệnh nhân
list_patient = []

def add_patient():
    # lấy thông tin từ các entry
    weight_value = float(weight.get())
    height_value = float(height.get())
    name_value = name.get()
    age_value = int(age.get())
    
    # khởi tạo đối tượng
    patient = Patient(name_value, age_value, height_value, weight_value)
    
    # thêm đối tượng vào danh sách
    list_patient.append(patient)
    
    showinfo("Healthcare System", "Patient added successfully!")
    

def search_patient():
    search_name_value = search_name.get()
    for patient in list_patient:
        if search_name_value in patient.name:
            showinfo("Search result", f"{patient.name} - BMI: {patient.bmi} - Age: {patient.age}")
            break
    
# Button
add_btn = Button(window, text="Add", command=add_patient)
search_btn = Button(window, text="Search", command=search_patient)

intro_lbl.grid(row=0, column=0, columnspan=2)
my_name_lbl.grid(row=1,column=0),
name.grid(row=1,column=1)
my_age_lbl.grid(row = 2, column = 0)
age.grid(row = 2, column = 1)
my_weight_lbl.grid(row = 3, column = 0)
weight.grid(row=3, column=1)
my_height_lbl.grid(row=4, column=0)
height.grid(row=4, column=1)
add_btn.grid(row=5, column=1)

search_lbl.grid(row=6, column=0)
search_name.grid(row=6, column=1)
search_btn.grid(row=6, column=2)

window.mainloop()

# %%
class Patient:
    def __init__(self,name, age, height, weight):
        self.name = name
        self.age = age
        self.height = height
        self.weight = weight
        self.bmi = weight/height **2
        

from tkinter import *
from tkinter import messagebox

window = Tk()
window.title("BMI Calculator")
window.geometry("500x300")
 
#label
intro_lbl = Label(window, text = "Healthcare System")
my_weight_lbl = Label(window, text = "My weight (kg)")
my_height_lbl = Label(window, text = "My height (m)")
my_name_lbl = Label(window, text = "My name")
my_age_lbl =  Label(window, text= "My age")
search_lbl = Label(window, text = "Search")


#Entry
weight = Entry(window)
height = Entry(window)
name = Entry(window)
age = Entry(window)
search_name = Entry(window)

#List patien duoc su dung de luu tru thong tin cac benh nhan
list_patient = []

def add_patient():
    weight_value = float(weight.get())
    height_value = float(height.get())
    name_value = name.get()
    age_value = int(age.get())
    # khoi tao doi tuong
    patient = Patient(name_value, age_value, height_value, weight_value)
    # them doi tuong vao danh sach
    list_patient.append(patient)
    
    messagebox.showinfo("Healthcare System","Patient added successfully!")

def search_patient():
    search_name_value = search_name.get()
    for patient in list_patient:
        print(patient.name)
        if search_name_value in patient.name:
            showinfo("Search result", f'{patient.name}')
            break
    
#Button
add_btn = Button(window, text = "Add", command = calc_bmi)
search_btn = Button(window, text = "Search", command = search_patient)

#place
intro_lbl.grid(row = 0, column = 0, columnspan = 2)
my_name_lbl.grid(row = 1, column = 0)
my_age_lbl.grid(row = 2, column = 0)
my_weight_lbl.grid(row = 3, column = 0)
my_height_lbl.grid(row = 4, column = 0)
name.grid(row =1, column = 1)
age.grid(row =2, column= 1) 
weight.grid(row =3, column = 1)
height.grid(row =4, column= 1) 
add_btn.grid(row = 5, column = 1)
search_lbl.grid(row = 6, column = 0)
search_name.grid(row = 6, column = 1)
search_btn.grid(row = 6, column = 2)

window.mainloop()
# Out:
# Weight value: 1.0
# Height value: 1.0
# BMI: 1.0

# %%
class Patient:
    def __int__(self, name, age, weight, height):
        self.name = name
        self.age = age
        self.height = height
        self.weight = weight
        self.bmi = weight / height ** 2

class Patient:
    def __init__(self, name, age, height, weight):
        self.name = name
        self.age = age
        self.height = height
        self.weight = weight
        self.bmi = weight / height ** 2

from tkinter import *
from tkinter.messagebox import showinfo

window = Tk()
window.title("Healthcare System")
window.geometry("500x300")

#label
intro_lbl = Label(window, text = "BMI Calculator")
my_weight_lbl = Label(window, text = "My weight(kg)")
my_height_lbl = Label(window, text = "My height(cm)")
my_name_lbl = Label(window, text = "My name")
my_age_lbl = Label(window, text = "My age")
search_lbl = Label(window, text = "Search:")

Entry
weight = Entry(window)
height = Entry(window)
name = Entry(window)
age = Entry(window)
search_name = Entry(window)
# list_patien được sử dụng để lưu trữ thông tin các bệnh nhân
list_patient= []

def add_patient():
    # lấy các thông tin từ Entry
    weight_value = float(weight.get())
    height_value = float(height.get())
    name_value = name.get()
    age_value = age.get()
    
    # khởi tạo đối tượng
    patient = Patient(name_value, age_value, weight_value, height_value)
    
    #Thêm đối tượng vào danh sách
    list_patient.append(patient)
    
    messagebox.showinfo("Healthcare System", "Patient added successfully!")
def search_patient():
    search_name_value = search_name.get()
    for patient in list_patient:
        if search_name_value in patient.name:
            showinfo("Search result", f"{patient.name} - BMI: {patient.bmi} - Age: {patient.age}")
            break
    
    
# Button
add_btn = Button(window, text = "Add", command= add_patient)
search_btn = Button(window, text = "Search", command=search_patient)

intro_lbl.grid(row=0, column=0, columnspan=2)
my_name_lbl.grid(row=1, column=0)
my_age_lbl.grid(row=2, column=0)
my_weight_lbl.grid(row=3, column=0)
my_height_lbl.grid(row=4, column=0)
name.grid(row=1, column=1)
age.grid(row=2, column=1)
weight.grid(row=3, column=1)
height.grid(row=4, column=1)
add_btn.grid(row=5, column=1)

search_lbl.grid(row=6, column=0)
search_name.grid(row=6, column=1)
search_btn.grid(row=6, column=2)

window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\longl\appdata\local\programs\python\python39\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\longl\AppData\Local\Temp/ipykernel_15756/3893305635.py", line 41, in add_patient
#     patient = Patient(name_value, age_value, weight_value, height_value)
# TypeError: Patient() takes no arguments
