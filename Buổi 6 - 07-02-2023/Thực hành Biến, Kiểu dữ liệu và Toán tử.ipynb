# %%
# Bài 1
diem_toan = 8.5
diem_ly = 7.5
diem_hoa = 8
diem_trung_binh = (diem_toan + diem_ly + diem_hoa)/3
print(diem_trung_binh)
# Out:
# 8.0

# %%
print(diem_trung_binh >= 8)
# Out:
# True

# %%
print(6<= diem_trung_binh and diem_trung_binh < 8)
# Out:
# False

# %%
print(6<= diem_trung_binh < 8)
# Out:
# False

# %%
print(diem_trung_binh < 6)
# Out:
# False

# %%
# Bài 2
di_hoc = 0.75
lam_bai = 0.85
diem_thi = 7.5
print(di_hoc > 0.75 and lam_bai > 0.85 and diem_thi >= 7.5)
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bài 3
speed_m = (33 * 1000)/60
speed = 33/60
print(speed_m)

length = speed * (60+12)
print(length)
# Out:
# 550.0
# 39.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bài 4
length = 16
width = 10
area = length * width

length_new = length + 4
area_new = width * length_new

print(area_new/area -1)
# Out:
# 0.25
